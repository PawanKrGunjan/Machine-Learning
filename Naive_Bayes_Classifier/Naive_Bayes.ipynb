# %% [markdown]
# ![image.png](attachment:f609488e-1550-4a4a-ba0a-d64b9056ce5b.png)

# %% [markdown]
# # Naive Bayes Classifiers

# %% [markdown]
# ### Bayes’ Theorem
# Bayes’ Theorem finds the probability of an event occurring given the probability of another event that has already occurred. Bayes’ theorem is stated mathematically as the following equation:
#
# ![image.png](attachment:2f72419f-a2ef-4849-a124-1f2f09e3b0a4.png)

# %% [markdown]
# ![image.png](attachment:d1452e43-0ccc-4898-94aa-af8a8f62c432.png)

# %% [markdown]
# ![image.png](attachment:39b3fbdf-e95b-403b-b6ab-cc7707573829.png)

# %% [markdown]
# today = (Sunny, Hot, Normal, False)

# %% [markdown]
# ![image.png](attachment:5c0534b7-59d6-4159-8197-ea1534678668.png)

# %% [markdown]
# ![image.png](attachment:277d72d3-e455-4610-9b45-342e0ab0ae0c.png)

# %% [markdown]
# ![image.png](attachment:b3a81887-6242-431d-9ac6-047f83b7e67a.png)

# %% [markdown]
# ![image.png](attachment:337b6eaf-6bc2-4e0f-998e-e802d403f1c2.png)

# %% [markdown]
# ![image.png](attachment:9831bfed-94a4-4f12-89f4-113df1911719.png)

# %% [markdown]
# * **So, prediction that golf would be played is ‘Yes’.**

# %% [markdown]
# # Gaussian Naive Bayes classifier

# %% [markdown]
# In Gaussian Naive Bayes, continuous values associated with each feature are assumed to be distributed according to a Gaussian distribution. A Gaussian distribution is also called Normal distribution. When plotted, it gives a bell shaped curve which is symmetric about the mean of the feature values as shown below:
# ![image.png](attachment:ad9c3118-1cd1-4f20-bf0c-336dcd54d2ec.png)
#
# ![image.png](attachment:0ee01420-703a-478f-a3b4-2b25b20ab3ab.png)

# %%
# Load the dataset
from sklearn.datasets import load_iris
iris = load_iris()

# %%
X = iris.data
y= iris.target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=2)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((120, 4), (30, 4), (120,), (30,))

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()

# %%
nb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = nb.predict(X_test)

# %%
nb.score(X_test,y_test)
# Out:
# 0.9666666666666667

# %% [markdown]
# * **Multinomial Naive Bayes:** Feature vectors represent the frequencies with which certain events have been generated by a multinomial distribution. This is the event model typically used for document classification

# %% [markdown]
# * **Bernoulli Naive Bayes:** In the multivariate Bernoulli event model, features are independent booleans (binary variables) describing inputs. Like the multinomial model, this model is popular for document classification tasks, where binary term occurrence(i.e. a word occurs in a document or not) features are used rather than term frequencies(i.e. frequency of a word in the document).
